# %%
print("chaitanya")
# Out:
# chaitanya

# %%
name = "Chaitanya"
print(name)
# Out:
# Chaitanya

# %%
name = "Chaitanya K"
age = 30
height = 5.7
is_student = True
print("Name :", name)
print("Age :", age)
print("Height :", height)
print("Student :", is_student)
# Out:
# Name : Chaitanya K
# Age : 30
# Height : 5.7
# Student : True

# %%
name = input()
age = int(input())
print("My name is ",name,".My age is ",age)
# Out:
#  chaitanya
#  0
# My name is  chaitanya .My age is  0

# %%
"""this is a comment"""
# Out:
# 'this is a comment'

# %%
# Excercise 1 : Write a program that asks for your name and favorite color and prints a message like:
# Hello Chaitanya, your favorite color is Blue!

name = input()
color = input()

print("Hello",name,"Your favourite color is",color)
# Out:
#  Chaitanya
#  Red
# Hello Chaitanya Your favourite color is  Red

# %%
# Excercise 2 : Write a program that takes two numbers from the user and prints their sum.
a = int(input())
b = int(input())
print(a+b)
# Out:
#  10
#  20
# 30
